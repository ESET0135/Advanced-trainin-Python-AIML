# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x=6*np.random.rand(100,1)-3
y=0.5*x**2+2+np.random.randn(100,1)
plt.scatter(x,y,color='g')
plt.xlabel('X data')
plt.ylabel('Y data')
# Out:
# Text(0, 0.5, 'Y data')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
LR=LinearRegression(n_jobs=-1)
LR.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
x_train
# Out:
# array([[ 1.17426734],
#        [ 1.71206899],
#        [-0.87203382],
#        [-1.56050861],
#        [ 1.04562328],
#        [ 0.78413513],
#        [ 0.81928302],
#        [-1.04853146],
#        [-0.6143133 ],
#        [ 1.10865301],
#        [-1.43049633],
#        [ 2.59384535],
#        [ 0.13410107],
#        [-1.93946992],
#        [ 1.40416703],
#        [ 0.09676775],
#        [-0.30539759],
#        [ 2.62396687],
#        [ 2.87929466],
#        [ 1.44104259],
#        [ 0.8153984 ],
#        [-0.67456096],
#        [ 1.01758341],
#        [ 0.41032196],
#        [-2.90919128],
#        [ 0.86318174],
#        [ 0.46459128],
#        [-2.00667793],
#        [ 2.28114803],
#        [ 1.72455573],
#        [-1.35147349],
#        [ 2.70345378],
#        [-0.53177761],
#        [ 0.42658534],
#        [-2.92263885],
#        [ 1.42137263],
#        [ 1.88144633],
#        [-2.18756223],
#        [ 2.05306414],
#        [-1.73020292],
#        [ 2.15694158],
#        [ 1.03061395],
#        [ 0.07429804],
#        [ 1.19791492],
#        [-2.8439851 ],
#        [ 1.42608326],
#        [ 0.46703331],
#        [ 0.33110788],
#        [-2.22080329],
#        [ 1.90331722],
#        [-2.47778814],
#        [ 1.66195783],
#        [-1.27263216],
#        [-2.40908769],
#        [-2.11616674],
#        [ 2.26382812],
#        [-2.36187728],
#        [ 1.0957386 ],
#        [ 1.64757597],
#        [ 2.02790636],
#        [-0.19284658],
#        [-1.28501603],
#        [-2.30197789],
#        [-0.34810178],
#        [ 1.08910701],
#        [ 0.5352342 ],
#        [ 2.80201209],
#        [-0.20955803],
#        [-2.38437312],
#        [ 1.55302853],
#        [ 2.09587061],
#        [ 1.3827712 ],
#        [ 2.17722453],
#        [-0.78694343],
#        [ 1.372973  ]])

# %%
plt.scatter(x_train,y_train,c='red')
plt.plot(x_train,LR.predict(x_train))

# %%
plt.scatter(x_train,y_train,c='red')
plt.plot(x_train,LR.predict(x_train))

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2,include_bias=True)
x_trainpoly=poly.fit_transform(x_train)
x_testpoly=poly.transform(x_test)

# %%
x_trainpoly
# Out:
# array([[ 1.00000000e+00,  1.17426734e+00,  1.37890380e+00],
#        [ 1.00000000e+00,  1.71206899e+00,  2.93118022e+00],
#        [ 1.00000000e+00, -8.72033821e-01,  7.60442985e-01],
#        [ 1.00000000e+00, -1.56050861e+00,  2.43518712e+00],
#        [ 1.00000000e+00,  1.04562328e+00,  1.09332803e+00],
#        [ 1.00000000e+00,  7.84135134e-01,  6.14867908e-01],
#        [ 1.00000000e+00,  3.31107880e-01,  1.09632428e-01],
#        [ 1.00000000e+00, -2.22080329e+00,  4.93196726e+00],
#        [ 1.00000000e+00,  1.90331722e+00,  3.62261644e+00],
#        [ 1.00000000e+00, -2.47778814e+00,  6.13943408e+00],
#        [ 1.00000000e+00,  1.66195783e+00,  2.76210384e+00],
#        [ 1.00000000e+00, -1.27263216e+00,  1.61959261e+00],
#        [ 1.00000000e+00, -2.40908769e+00,  5.80370348e+00],
#        [ 1.00000000e+00, -2.11616674e+00,  4.47816166e+00],
#        [ 1.00000000e+00,  2.26382812e+00,  5.12491777e+00],
#        [ 1.00000000e+00, -2.36187728e+00,  5.57846429e+00],
#        [ 1.00000000e+00,  1.09573860e+00,  1.20064307e+00],
#        [ 1.00000000e+00,  1.64757597e+00,  2.71450657e+00],
#        [ 1.00000000e+00,  2.02790636e+00,  4.11240419e+00],
#        [ 1.00000000e+00, -1.92846583e-01,  3.71898046e-02],
#        [ 1.00000000e+00, -1.28501603e+00,  1.65126620e+00],
#        [ 1.00000000e+00, -2.30197789e+00,  5.29910221e+00],
#        [ 1.00000000e+00, -3.48101775e-01,  1.21174846e-01],
#        [ 1.00000000e+00,  1.08910701e+00,  1.18615409e+00],
#        [ 1.00000000e+00,  5.35234204e-01,  2.86475653e-01],
#        [ 1.00000000e+00,  2.80201209e+00,  7.85127174e+00],
#        [ 1.00000000e+00, -2.09558034e-01,  4.39145697e-02],
#        [ 1.00000000e+00, -2.38437312e+00,  5.68523519e+00],
#        [ 1.00000000e+00,  1.55302853e+00,  2.41189762e+00],
#        [ 1.00000000e+00,  2.09587061e+00,  4.39267361e+00],
#        [ 1.00000000e+00,  1.38277120e+00,  1.91205619e+00],
#        [ 1.00000000e+00,  2.17722453e+00,  4.74030664e+00],
#        [ 1.00000000e+00, -7.86943427e-01,  6.19279957e-01],
#        [ 1.00000000e+00,  1.37297300e+00,  1.88505487e+00]])

# %%
LR.fit(x_trainpoly,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
plt.scatter(x_train, y_train, color='red')
x_sorted = np.sort(x_train, axis=0)
plt.plot(x_sorted, LR.predict(poly.transform(x_sorted)), color='blue')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3,include_bias=True)
x_trainpoly=poly.fit_transform(x_train)
x_testpoly=poly.transform(x_test)

# %%
from sklearn.pipeline import Pipeline
def poly_regression(degree):
    x_new = np.linspace(-3,3,200).reshape(200,1)

    poly_features = PolynomialFeatures(degree=degree,include_bias=True)
    lin_reg=LinearRegression()
    poly_regression=Pipeline(
        [
            ("poly_features",poly_features),
            ("lin_reg",lin_reg)
        ]
    )
    poly_regression.fit(x_train,y_train)
    y_pred_new = poly_regression.predict(x_new)
    plt.plot(x_new,y_pred_new,'r',label="Degree"+str(degree),linewidth=2)
    plt.scatter(x_train,y_train,color="blue",linewidth=3)
    plt.scatter(x_test,y_test,color="green",linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axis([-4,4,0,10])
    plt.show()

# %%
poly_regression(3)
